# %% [markdown]
# # 폐렴 진단기 성능개선
#
# 딥러닝 모델이 X-ray 사진을 보고 폐렴 여부를 진단합니다.
# 정상적인

# %%
import os, re
import random, math
import numpy as np
import tensorflow as tf
import matplotlib.pyplot as plt

# %%
# 데이터 로드할 때 빠르게 로드할 수 있도록하는 설정 변수
AUTOTUNE = tf.data.experimental.AUTOTUNE
# X-RAY 이미지 사이즈 변수
IMAGE_SIZE = [180, 180]

# 데이터 경로 변수
ROOT_PATH = os.path.join(os.getenv('HOME'), 'aiffel')
TRAIN_PATH = ROOT_PATH + '/chest_xray/data/train/*/*'
VAL_PATH = ROOT_PATH + '/chest_xray/data/val/*/*'
TEST_PATH = ROOT_PATH + '/chest_xray/data/test/*/*'

# 프로젝트를 진행할 때 아래 두 변수를 변경해보세요
BATCH_SIZE = 16
EPOCHS = 25

print(ROOT_PATH)
# Out:
# /aiffel/aiffel

# %% [markdown]
# # 데이터 준비하기

# %%
train_filenames = tf.io.gfile.glob(TRAIN_PATH)
test_filenames = tf.io.gfile.glob(TEST_PATH)
val_filenames = tf.io.gfile.glob(VAL_PATH)

print('훈련 데이터 갯수: {}'.format(len(train_filenames)))
print('테스트 데이터 갯수: {}'.format(len(test_filenames)))
print('검증 데이터 갯수: {}'.format(len(val_filenames)))
# Out:
# 훈련 데이터 갯수: 5216
# 테스트 데이터 갯수: 624
# 검증 데이터 갯수: 16

# %%
# train 데이터와 validation 데이터를 모두 filenames에 담습니다
filenames = tf.io.gfile.glob(TRAIN_PATH)
filenames.extend(tf.io.gfile.glob(VAL_PATH))

# 모아진 filenames를 8:2로 나눕니다
train_size = math.floor(len(filenames)*0.8)
random.seed(8)
random.shuffle(filenames)
train_filenames = filenames[:train_size]
val_filenames = filenames[train_size:]

print('훈련 데이터 갯수: {}'.format(len(train_filenames)))
print('검증 데이터 갯수: {}'.format(len(val_filenames)))
# Out:
# 훈련 데이터 갯수: 4185
# 검증 데이터 갯수: 1047

# %%
# 정상 또는 폐렴 이미지 확인
print(f'Normal image path\n{filenames[0]}')
print(f'Pneumonia image path\n{filenames[2000]}')
# Out:
# Normal image path
# /aiffel/aiffel/chest_xray/data/train/NORMAL/IM-0447-0001.jpeg
# Pneumonia image path
# /aiffel/aiffel/chest_xray/data/train/PNEUMONIA/person614_bacteria_2483.jpeg

# %%
# 이제 파일 경로에 NORMAL이 있는지 확인하면 정상 이미지를 셀 수 있습니다.
COUNT_NORMAL = len([filename for filename in train_filenames if "NORMAL" in filename])
print(f"Normal images count in training set: {COUNT_NORMAL}")

# 파일 경로에 PNEUMONIA이 있는지 확인하면 폐렴 이미지도 셀 수 있습니다.
COUNT_PNEUMONIA = len([filename for filename in train_filenames if "PNEUMONIA" in filename])
print(f"Pneumonia images count in training set: {COUNT_PNEUMONIA}")
# Out:
# Normal images count in training set: 1070
# Pneumonia images count in training set: 3115

# %%
train_list_ds = tf.data.Dataset.from_tensor_slices(train_filenames)
val_list_ds = tf.data.Dataset.from_tensor_slices(val_filenames)

# %%
TRAIN_IMG_COUNT = tf.data.experimental.cardinality(train_list_ds).numpy()
print(f"Training images count: {TRAIN_IMG_COUNT}")

VAL_IMG_COUNT = tf.data.experimental.cardinality(val_list_ds).numpy()
print(f"Validating images count: {VAL_IMG_COUNT}")
# Out:
# Training images count: 4185
# Validating images count: 1047

# %%
# 파일 경로의 끝에서 두번째 부분을 확인하면 양성과 음성을 구분할 수 있습니다
def get_label(file_path):
    parts = tf.strings.split(file_path, os.path.sep)
    return parts[-2] == "PNEUMONIA"   # 폐렴이면 양성(True), 노말이면 음성(False)

# %%
# 이미지를 알맞은 형식으로 바꿉니다.
def decode_img(img):
    img = tf.image.decode_jpeg(img, channels=3) # 이미지를 uint8 tensor로 수정
    img = tf.image.convert_image_dtype(img, tf.float32) # float32 타입으로 수정
    img = tf.image.resize(img, IMAGE_SIZE) # 이미지 사이즈를 IMAGE_SIZE로 수정
    return img

# 이미지 파일의 경로를 입력하면 이미지와 라벨을 읽어옵니다.
def process_path(file_path):
    label = get_label(file_path) # 라벨 검출
    img = tf.io.read_file(file_path) # 이미지 읽기
    img = decode_img(img) # 이미지를 알맞은 형식으로 수정
    return img, label

# %%
train_ds = train_list_ds.map(process_path, num_parallel_calls=AUTOTUNE)
val_ds = val_list_ds.map(process_path, num_parallel_calls=AUTOTUNE)

# %%
for image, label in train_ds.take(1):
    print("Image shape: ", image.numpy().shape)
    print("Label: ", label.numpy())
# Out:
# Image shape:  (180, 180, 3)
# Label:  False

# %%
# 테스트 데이터도 동일한 작업을 해줍니다.
test_list_ds = tf.data.Dataset.list_files(TEST_PATH)
TEST_IMAGE_COUNT = tf.data.experimental.cardinality(test_list_ds).numpy()
test_ds = test_list_ds.map(process_path, num_parallel_calls=AUTOTUNE)
test_ds = test_ds.batch(BATCH_SIZE)

print('테스트 데이터 갯수: {}'.format(TEST_IMAGE_COUNT))
# Out:
# 테스트 데이터 갯수: 624

# %%
def prepare_for_training(ds, shuffle_buffer_size=1000):
    ds = ds.shuffle(buffer_size=shuffle_buffer_size)
    ds = ds.repeat()
    ds = ds.batch(BATCH_SIZE)
    ds = ds.prefetch(buffer_size=AUTOTUNE)
    return ds

train_ds = prepare_for_training(train_ds)
val_ds = prepare_for_training(val_ds)

# %% [markdown]
# # 데이터 시각화

# %%
# 이미지 배치를 입력하면 여러장의 이미지를 보여줍니다.
def show_batch(image_batch, label_batch):
    plt.figure(figsize=(10,10))
    for n in range(BATCH_SIZE):
        ax = plt.subplot(5,math.ceil(BATCH_SIZE/5),n+1)
        plt.imshow(image_batch[n])
        if label_batch[n]:
            plt.title("PNEUMONIA")
        else:
            plt.title("NORMAL")
        plt.axis("off")


image_batch, label_batch = next(iter(train_ds))
show_batch(image_batch.numpy(), label_batch.numpy())

# %% [markdown]
# # 모델링

# %%
def conv_block(filters):
    block = tf.keras.Sequential([
        tf.keras.layers.SeparableConv2D(filters, 3, activation='relu', padding='same'),
        tf.keras.layers.SeparableConv2D(filters, 3, activation='relu', padding='same'),
        tf.keras.layers.BatchNormalization(),
        tf.keras.layers.MaxPool2D()
    ])
    
    return block

# %%
def dense_block(units, dropout_rate):
    block = tf.keras.Sequential([
        tf.keras.layers.Dense(units, activation='relu'),
        tf.keras.layers.BatchNormalization(),
        tf.keras.layers.Dropout(dropout_rate)
    ])
    
    return block

# %%
def build_model():
    model = tf.keras.Sequential([
        tf.keras.Input(shape=(IMAGE_SIZE[0], IMAGE_SIZE[1], 3)),
        
        tf.keras.layers.Conv2D(16, 3, activation='relu', padding='same'),
        tf.keras.layers.Conv2D(16, 3, activation='relu', padding='same'),
        tf.keras.layers.MaxPool2D(),
        
        conv_block(32),
        conv_block(64),
        
        conv_block(128),
        tf.keras.layers.Dropout(0.2),
        
        conv_block(256),
        tf.keras.layers.Dropout(0.2),
        
        tf.keras.layers.Flatten(),
        dense_block(512, 0.7),
        dense_block(128, 0.5),
        dense_block(64, 0.3),
        
        tf.keras.layers.Dense(1, activation='sigmoid')
    ])
    
    return model

# %% [markdown]
# # 데이터 imbalance 처리

# %%
weight_for_0 = (1 / COUNT_NORMAL)*(TRAIN_IMG_COUNT)/2.0 
weight_for_1 = (1 / COUNT_PNEUMONIA)*(TRAIN_IMG_COUNT)/2.0

class_weight = {0: weight_for_0, 1: weight_for_1}

print('Weight for NORMAL: {:.2f}'.format(weight_for_0))
print('Weight for PNEUMONIA: {:.2f}'.format(weight_for_1))
# Out:
# Weight for NORMAL: 1.96
# Weight for PNEUMONIA: 0.67

# %% [markdown]
# # 모델 학습

# %%
with tf.device('/GPU:0'):
    model = build_model()

    METRICS = [
        'accuracy',
        tf.keras.metrics.Precision(name='precision'),
        tf.keras.metrics.Recall(name='recall')
    ]
    
    model.compile(
        optimizer='adam',
        loss='binary_crossentropy',
        metrics=METRICS
    )

# %%
model.summary()
# Out:
# Model: "sequential_15"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_2 (Conv2D)            (None, 180, 180, 16)      448
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 180, 180, 16)      2320
# _________________________________________________________________
# max_pooling2d_5 (MaxPooling2 (None, 90, 90, 16)        0
# _________________________________________________________________
# sequential_8 (Sequential)    (None, 45, 45, 32)        2160
# _________________________________________________________________
# sequential_9 (Sequential)    (None, 22, 22, 64)        7392
# _________________________________________________________________
# sequential_10 (Sequential)   (None, 11, 11, 128)       27072
# _________________________________________________________________
# dropout_5 (Dropout)          (None, 11, 11, 128)       0
# _________________________________________________________________
# sequential_11 (Sequential)   (None, 5, 5, 256)         103296
# _________________________________________________________________
# dropout_6 (Dropout)          (None, 5, 5, 256)         0
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 6400)              0
# _________________________________________________________________
# sequential_12 (Sequential)   (None, 512)               3279360
# _________________________________________________________________
# sequential_13 (Sequential)   (None, 128)               66176
# _________________________________________________________________
# sequential_14 (Sequential)   (None, 64)                8512
# _________________________________________________________________
# dense_7 (Dense)              (None, 1)                 65
# =================================================================
# Total params: 3,496,801
# Trainable params: 3,494,433
# Non-trainable params: 2,368
# _________________________________________________________________

# %%
checkpoint_filepath = './checkpoint'
model_checkpoint_callback = tf.keras.callbacks.ModelCheckpoint(
    filepath=checkpoint_filepath,
    save_weights_only=True,
    monitor='val_accuracy',
    mode='max',
    save_best_only=True
)

early_stopping = tf.keras.callbacks.EarlyStopping(patience=10, restore_best_weights=True)

with tf.device('/GPU:0'):
    history = model.fit(
        train_ds,
        steps_per_epoch=TRAIN_IMG_COUNT // BATCH_SIZE,
        epochs=EPOCHS,
        validation_data=val_ds,
        validation_steps=VAL_IMG_COUNT // BATCH_SIZE,
        class_weight=class_weight,
        callbacks=[early_stopping, model_checkpoint_callback],
    )
# Out:
# Epoch 1/25
# 261/261 [==============================] - 72s 230ms/step - loss: 0.5452 - accuracy: 0.7107 - precision: 0.9153 - recall: 0.6686 - val_loss: 0.5953 - val_accuracy: 0.7346 - val_precision: 0.7346 - val_recall: 1.0000
# Epoch 2/25
# 261/261 [==============================] - 59s 225ms/step - loss: 0.2449 - accuracy: 0.8976 - precision: 0.9693 - recall: 0.8916 - val_loss: 1.0506 - val_accuracy: 0.7327 - val_precision: 0.7327 - val_recall: 1.0000
# Epoch 3/25
# 261/261 [==============================] - 59s 225ms/step - loss: 0.1817 - accuracy: 0.9268 - precision: 0.9793 - recall: 0.9223 - val_loss: 0.4440 - val_accuracy: 0.8058 - val_precision: 0.7905 - val_recall: 1.0000
# Epoch 4/25
# 261/261 [==============================] - 59s 227ms/step - loss: 0.1532 - accuracy: 0.9414 - precision: 0.9896 - recall: 0.9315 - val_loss: 0.1238 - val_accuracy: 0.9538 - val_precision: 0.9986 - val_recall: 0.9384
# Epoch 5/25
# 261/261 [==============================] - 60s 230ms/step - loss: 0.1578 - accuracy: 0.9370 - precision: 0.9824 - recall: 0.9327 - val_loss: 0.1171 - val_accuracy: 0.9519 - val_precision: 0.9931 - val_recall: 0.9410
# Epoch 6/25
# 261/261 [==============================] - 61s 235ms/step - loss: 0.1412 - accuracy: 0.9440 - precision: 0.9863 - recall: 0.9395 - val_loss: 0.1428 - val_accuracy: 0.9462 - val_precision: 0.9315 - val_recall: 1.0000
# Epoch 7/25
# 261/261 [==============================] - 66s 252ms/step - loss: 0.1388 - accuracy: 0.9473 - precision: 0.9823 - recall: 0.9466 - val_loss: 0.0712 - val_accuracy: 0.9808 - val_precision: 0.9882 - val_recall: 0.9856
# Epoch 8/25
# 261/261 [==============================] - 57s 218ms/step - loss: 0.1366 - accuracy: 0.9506 - precision: 0.9889 - recall: 0.9449 - val_loss: 0.7088 - val_accuracy: 0.7423 - val_precision: 1.0000 - val_recall: 0.6492
# Epoch 9/25
# 261/261 [==============================] - 58s 223ms/step - loss: 0.1583 - accuracy: 0.9354 - precision: 0.9853 - recall: 0.9283 - val_loss: 0.1141 - val_accuracy: 0.9577 - val_precision: 0.9945 - val_recall: 0.9476
# Epoch 10/25
# 261/261 [==============================] - 56s 215ms/step - loss: 0.1368 - accuracy: 0.9529 - precision: 0.9867 - recall: 0.9496 - val_loss: 0.0951 - val_accuracy: 0.9654 - val_precision: 0.9959 - val_recall: 0.9567
# Epoch 11/25
# 261/261 [==============================] - 56s 216ms/step - loss: 0.1104 - accuracy: 0.9576 - precision: 0.9922 - recall: 0.9512 - val_loss: 0.0481 - val_accuracy: 0.9846 - val_precision: 0.9869 - val_recall: 0.9921
# Epoch 12/25
# 261/261 [==============================] - 57s 218ms/step - loss: 0.0986 - accuracy: 0.9625 - precision: 0.9912 - recall: 0.9584 - val_loss: 0.1694 - val_accuracy: 0.9298 - val_precision: 0.9986 - val_recall: 0.9058
# Epoch 13/25
# 261/261 [==============================] - 57s 217ms/step - loss: 0.1071 - accuracy: 0.9621 - precision: 0.9911 - recall: 0.9574 - val_loss: 0.0647 - val_accuracy: 0.9740 - val_precision: 0.9855 - val_recall: 0.9790
# Epoch 14/25
# 261/261 [==============================] - 57s 218ms/step - loss: 0.1017 - accuracy: 0.9675 - precision: 0.9923 - recall: 0.9636 - val_loss: 0.0890 - val_accuracy: 0.9596 - val_precision: 0.9959 - val_recall: 0.9490
# Epoch 15/25
# 261/261 [==============================] - 57s 217ms/step - loss: 0.1117 - accuracy: 0.9572 - precision: 0.9889 - recall: 0.9533 - val_loss: 0.6764 - val_accuracy: 0.7644 - val_precision: 1.0000 - val_recall: 0.6785
# Epoch 16/25
# 261/261 [==============================] - 58s 223ms/step - loss: 0.1148 - accuracy: 0.9571 - precision: 0.9936 - recall: 0.9490 - val_loss: 0.6673 - val_accuracy: 0.7885 - val_precision: 1.0000 - val_recall: 0.7117
# Epoch 17/25
# 261/261 [==============================] - 56s 216ms/step - loss: 0.0952 - accuracy: 0.9628 - precision: 0.9899 - recall: 0.9597 - val_loss: 0.0743 - val_accuracy: 0.9702 - val_precision: 0.9973 - val_recall: 0.9620
# Epoch 18/25
# 261/261 [==============================] - 57s 217ms/step - loss: 0.0831 - accuracy: 0.9665 - precision: 0.9919 - recall: 0.9627 - val_loss: 0.0664 - val_accuracy: 0.9760 - val_precision: 0.9792 - val_recall: 0.9882
# Epoch 19/25
# 261/261 [==============================] - 57s 219ms/step - loss: 0.0644 - accuracy: 0.9769 - precision: 0.9931 - recall: 0.9753 - val_loss: 0.0615 - val_accuracy: 0.9731 - val_precision: 0.9946 - val_recall: 0.9685
# Epoch 20/25
# 261/261 [==============================] - 57s 218ms/step - loss: 0.0598 - accuracy: 0.9821 - precision: 0.9977 - recall: 0.9784 - val_loss: 0.0643 - val_accuracy: 0.9769 - val_precision: 0.9768 - val_recall: 0.9921
# Epoch 21/25
# 261/261 [==============================] - 57s 218ms/step - loss: 0.0846 - accuracy: 0.9718 - precision: 0.9921 - recall: 0.9701 - val_loss: 0.0563 - val_accuracy: 0.9760 - val_precision: 0.9946 - val_recall: 0.9725

# %% [markdown]
# # 결과 확인 및 시각화

# %%
fig, ax = plt.subplots(1, 4, figsize=(20, 3))
ax = ax.ravel()

for i, met in enumerate(['precision', 'recall', 'accuracy', 'loss']):
    ax[i].plot(history.history[met])
    ax[i].plot(history.history['val_' + met])
    ax[i].set_title('Model {}'.format(met))
    ax[i].set_xlabel('epochs')
    ax[i].set_ylabel(met)
    ax[i].legend(['train', 'val'])

# %%
loss, accuracy, precision, recall = model.evaluate(test_ds)
print(f'Loss: {loss},\nAccuracy: {accuracy},\nPrecision: {precision},\nRecall: {recall}')
# Out:
# 39/39 [==============================] - 6s 145ms/step - loss: 0.8666 - accuracy: 0.7933 - precision: 0.7534 - recall: 0.9949
# Loss: 0.8666461110115051,
# Accuracy: 0.7932692170143127,
# Precision: 0.753398060798645,
# Recall: 0.9948717951774597
